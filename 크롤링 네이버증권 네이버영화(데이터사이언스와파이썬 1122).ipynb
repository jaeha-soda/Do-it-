# %%
from bs4 import BeautifulSoup

# %%
page = open('C:/Users/user/Downloads/test.html','r',encoding='utf-8').read()
page
# Out:
# '<!DOCTYPE html>\n<html>\n    <head>\n        <title>Very Simple HTML Code by PinkWink</title>\n    </head>\n    <body>\n        <div>\n            <p class="inner-text first-item" id="first">\n                Happy PinkWink.\n                <a href="http://www.kyungnam.ac.kr" id="pw-link">경남대학교</a>\n            </p>\n            <p class="inner-text second-item">\n                Happy Data Science.\n                <a href="https://www.python.org" id="py-link">Python</a>\n            </p>\n        </div>\n        <p class="outer-text first-item" id="second">\n            <b>\n                Data Science is funny.\n            </b>\n        </p>\n        <p class="outer-text">\n            <b>\n                All I need is Love.\n            </b>\n        </p>\n    </body>\n</html>'

# %%
soup = BeautifulSoup(page, 'html.parser')
print(soup.prettify())  #  html 페이지의 내용을 전체 다 보고 싶으면 prettify()  옵션 사용
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Very Simple HTML Code by PinkWink
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     Happy PinkWink.
#     <a href="http://www.kyungnam.ac.kr" id="pw-link">
#      경남대학교
#     </a>
#    </p>
#    <p class="inner-text second-item">
#     Happy Data Science.
#     <a href="https://www.python.org" id="py-link">
#      Python
#     </a>
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     Data Science is funny.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     All I need is Love.
#    </b>
#   </p>
#  </body>
# </html>

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  <html>
#  <head>
#  <title>Very Simple HTML Code by PinkWink</title>
#  </head>
#  <body>
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.kyungnam.ac.kr" id="pw-link">경남대학교</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>
#  </body>
#  </html>]

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>Very Simple HTML Code by PinkWink</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.kyungnam.ac.kr" id="pw-link">경남대학교</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>
# </html>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
html = list(html.children)[3]
html
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.kyungnam.ac.kr" id="pw-link">경남대학교</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
soup.body
# Out:
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 Happy PinkWink.
#                 <a href="http://www.kyungnam.ac.kr" id="pw-link">경남대학교</a>
# </p>
# <p class="inner-text second-item">
#                 Happy Data Science.
#                 <a href="https://www.python.org" id="py-link">Python</a>
# </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 All I need is Love.
#             </b>
# </p>
# </body>

# %%
list(html.children)
# Out:
# ['\n',
#  <div>
#  <p class="inner-text first-item" id="first">
#                  Happy PinkWink.
#                  <a href="http://www.kyungnam.ac.kr" id="pw-link">경남대학교</a>
#  </p>
#  <p class="inner-text second-item">
#                  Happy Data Science.
#                  <a href="https://www.python.org" id="py-link">Python</a>
#  </p>
#  </div>,
#  '\n',
#  <p class="outer-text first-item" id="second">
#  <b>
#                  Data Science is funny.
#              </b>
#  </p>,
#  '\n',
#  <p class="outer-text">
#  <b>
#                  All I need is Love.
#              </b>
#  </p>,
#  '\n']

# %%
body = list(html.children)[3]
body
# Out:
# <p class="outer-text first-item" id="second">
# <b>
#                 Data Science is funny.
#             </b>
# </p>

# %%
list(body.children)
# Out:
# ['\n',
#  <b>
#                  Data Science is funny.
#              </b>,
#  '\n']

# %% [markdown]
# -----------------------

# %%
from urllib.request import urlopen

url = 'https://finance.naver.com/marketindex/'
page = urlopen(url)

soul = BeautifulSoup(page, 'html.parser')
soul
# Out:
# <script language="javascript" src="/template/head_js.naver?referer=info.finance.naver.com&amp;menu=marketindex&amp;submenu=market"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20211029233853/js/info/jindo.min.ns.1.5.3.euckr.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/imgstock/static.pc/20211029233853/js/jindo.1.5.3.element-text-patch.js" type="text/javascript"></script>
# <div id="container" style="padding-bottom:0px;">
# <div class="market_include">
# <div class="market_data">
# <div class="market1">
# <div class="title">
# <h2 class="h_market1"><span>환전 고시 환율</span></h2>
# </div>
# <!-- data -->
# <div class="data">
# <ul class="data_lst" id="exchangeList">
# <li class="on">
# <a class="head usd" href="/marketindex/exchangeDetail.naver?marketindexCd=FX_USDKRW" onclick="clickcr(this, 'fr1.usdt', '', '', event);">
# <h3 class="h_lst"><span class="blind">미국 USD</span></h3>
# <div class="head_info point_dn">
# ...

# %%
soul.find_all('span','value')[0].string
soul.find_all('span','source')[0].string
# Out:
# '하나은행 기준'

# %%
soul.find_all('span')
# Out:
# [<span>환전 고시 환율</span>,
#  <span class="blind">미국 USD</span>,
#  <span class="value">1,185.60</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 4.40</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2021.11.22 15:26</span>,
#  <span class="source">하나은행 기준</span>,
#  <span class="count">고시회차<span class="num">271</span>회</span>,
#  <span class="num">271</span>,
#  <span class="blind">일본 JPY(100엔)</span>,
#  <span class="value">1,038.50</span>,
#  <span class="txt_krw"><span class="blind">원</span></span>,
#  <span class="blind">원</span>,
#  <span class="change"> 6.05</span>,
#  <span class="blind">하락</span>,
#  <span class="time">2021.11.22 15:26</span>,
#  <span class="source">하나은행 기준</span>,
#  <span class="count">고시회차<span class="num">271</span>회</span>,
#  <span class="num">271</span>,
#  <span class="blind">유럽연합 EUR</span>,
#  <span class="value">1,336.82</span>,
# ...

# %%
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen

url = 'https://movie.naver.com/movie/sdb/rank/rmovie.naver?sel=cur&date=20211121'
page = urlopen(url)

soup = BeautifulSoup(page, 'html.parser')
soup.find_all('div','tit5')[:10]
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=189075" title="자산어보">자산어보</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=201073" title="코다">코다</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=205968" title="극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들">극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=199860" title="기적">기적</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=31475" title="파이란">파이란</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=185282" title="타오르는 여인의 초상">타오르는 여인의 초상</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=191545" title="라스트 듀얼: 최후의 결투">라스트 듀얼: 최후의 결투</a>
#  </div>,
#  <div class="tit5">
#  <a href="/movie/bi/mi/basic.naver?code=200896" title="꽃다발 같은 사랑을 했다">꽃다발 같은 사랑을 했다</a>
#  </div>,
#  <div class="tit5">
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
for i in range(0,10):
    print(soup.find_all('div','tit5')[i].a.string)
# Out:
# 자산어보
# 코다
# 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 기적
# 파이란
# 타오르는 여인의 초상
# 라스트 듀얼: 최후의 결투
# 꽃다발 같은 사랑을 했다
# 고장난 론
# 윤희에게

# %%
for i in range(0,30):
    print(soup.find_all('div','tit5')[i].a.string)
# Out:
# 자산어보
# 코다
# 극장판 짱구는 못말려: 격돌! 낙서왕국과 얼추 네 명의 용사들
# 기적
# 파이란
# 타오르는 여인의 초상
# 라스트 듀얼: 최후의 결투
# 꽃다발 같은 사랑을 했다
# 고장난 론
# 윤희에게
# 마담 프루스트의 비밀정원
# 리틀 포레스트
# 고양이를 부탁해
# 아멜리에
# 너의 이름은.
# 보이스
# 호빗 : 뜻밖의 여정
# 너의 췌장을 먹고 싶어
# 다가오는 것들
# 너의 췌장을 먹고 싶어
# 몽상가들
# 부산행
# 날씨의 아이
# 듄
# 악인전
# 신과함께-인과 연
# 시동
# 디어 에반 핸슨
# 아네트
# 퍼스널 쇼퍼

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
soup.find_all('td','point')[0].string
# Out:
# '9.33'

# %%
for i in range (0,10):
    print(soup.find_all('td','point')[i].string)
# Out:
# 9.33
# 9.24
# 9.22
# 9.19
# 9.08
# 9.06
# 9.03
# 9.00
# 8.97
# 8.97

# %% [markdown]
# 10월1일부터 52일간의 날짜를 정의하시오.

# %%
date = pd.date_range('2021-10-1', periods = 52)
date
# Out:
# DatetimeIndex(['2021-10-01', '2021-10-02', '2021-10-03', '2021-10-04',
#                '2021-10-05', '2021-10-06', '2021-10-07', '2021-10-08',
#                '2021-10-09', '2021-10-10', '2021-10-11', '2021-10-12',
#                '2021-10-13', '2021-10-14', '2021-10-15', '2021-10-16',
#                '2021-10-17', '2021-10-18', '2021-10-19', '2021-10-20',
#                '2021-10-21', '2021-10-22', '2021-10-23', '2021-10-24',
#                '2021-10-25', '2021-10-26', '2021-10-27', '2021-10-28',
#                '2021-10-29', '2021-10-30', '2021-10-31', '2021-11-01',
#                '2021-11-02', '2021-11-03', '2021-11-04', '2021-11-05',
#                '2021-11-06', '2021-11-07', '2021-11-08', '2021-11-09',
#                '2021-11-10', '2021-11-11', '2021-11-12', '2021-11-13',
#                '2021-11-14', '2021-11-15', '2021-11-16', '2021-11-17',
#                '2021-11-18', '2021-11-19', '2021-11-20', '2021-11-21'],
#               dtype='datetime64[ns]', freq='D')

# %%
import urllib
from tqdm import tqdm_notebook

movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = 'https://movie.naver.com/' + 'movie/sdb/rank/rmovie.naver?sel=cur&date={date}'
    response = urlopen(html.format( date = urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, 'html.parser')
    
    end = len(soup.find_all('td','point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td','point')[n].string for n in range(0,end)])
# Out:
# <ipython-input-78-e8055e96f5fa>:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for today in tqdm_notebook(date):
#   0%|          | 0/52 [00:00<?, ?it/s]

# %%
movie = pd.DataFrame({'date':movie_date, 'name':movie_name, 'point':movie_point})
movie
# Out:
#            date              name point
# 0    2021-10-01                밥정  9.63
# 1    2021-10-01              가버나움  9.59
# 2    2021-10-01                원더  9.53
# 3    2021-10-01                코다  9.35
# 4    2021-10-01     해리 포터와 마법사의 돌  9.35
# ...         ...               ...   ...
# 2141 2021-11-21                강릉  6.37
# 2142 2021-11-21  베놈 2: 렛 데어 비 카니지  6.14
# 2143 2021-11-21           노회찬6411  6.13
# 2144 2021-11-21              이터널스  5.58
# 2145 2021-11-21   고양이에게 밥을 주지 마세요  5.43
#
# [2146 rows x 3 columns]

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146 entries, 0 to 2145
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2146 non-null   datetime64[ns]
#  1   name    2146 non-null   object
#  2   point   2146 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 50.4+ KB

# %%
movie['point'] = movie['point'].astype(float)
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2146 entries, 0 to 2145
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    2146 non-null   datetime64[ns]
#  1   name    2146 non-null   object
#  2   point   2146 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 50.4+ KB

# %% [markdown]
# 영화별 점수 평균으로 정렬

# %%
import numpy as np

movie_unique = pd.pivot_table(movie, index = ['name'], aggfunc = np.mean)
movie_best = movie_unique.sort_values(by = 'point', ascending = False)
movie_best
# Out:
#                           point
# name
# 밥정                     9.623158
# 그린 북                   9.590000
# 가버나움                   9.590000
# 원더                     9.530000
# 해리 포터와 마법사의 돌          9.350000
# ...                         ...
# 반도                     5.639412
# 당신의 사월                 4.840000
# 고양이에게 밥을 주지 마세요        4.363750
# 120BPM                 2.770000
# 킹 오브 프리즘 -샤이니 세븐 스타즈-  2.150000
#
# [111 rows x 1 columns]

# %% [markdown]
# 영화 한 개 날짜별 평점 변화

# %%
bob = movie[movie['name'] == '밥정']
bob
# Out:
#           date name  point
# 0   2021-10-01   밥정   9.63
# 40  2021-10-02   밥정   9.63
# 77  2021-10-03   밥정   9.63
# 115 2021-10-04   밥정   9.63
# 152 2021-10-05   밥정   9.63
# 189 2021-10-06   밥정   9.63
# 227 2021-10-07   밥정   9.63
# 269 2021-10-08   밥정   9.63
# 311 2021-10-09   밥정   9.63
# 357 2021-10-10   밥정   9.63
# 398 2021-10-11   밥정   9.63
# 440 2021-10-12   밥정   9.64
# 484 2021-10-13   밥정   9.61
# 527 2021-10-14   밥정   9.61
# 571 2021-10-15   밥정   9.61
# 614 2021-10-16   밥정   9.61
# 656 2021-10-17   밥정   9.61
# 698 2021-10-18   밥정   9.61
# 740 2021-10-19   밥정   9.61

# %%
tmp = movie.query('name == ["밥정"]')
tmp
# Out:
#           date name  point
# 0   2021-10-01   밥정   9.63
# 40  2021-10-02   밥정   9.63
# 77  2021-10-03   밥정   9.63
# 115 2021-10-04   밥정   9.63
# 152 2021-10-05   밥정   9.63
# 189 2021-10-06   밥정   9.63
# 227 2021-10-07   밥정   9.63
# 269 2021-10-08   밥정   9.63
# 311 2021-10-09   밥정   9.63
# 357 2021-10-10   밥정   9.63
# 398 2021-10-11   밥정   9.63
# 440 2021-10-12   밥정   9.64
# 484 2021-10-13   밥정   9.61
# 527 2021-10-14   밥정   9.61
# 571 2021-10-15   밥정   9.61
# 614 2021-10-16   밥정   9.61
# 656 2021-10-17   밥정   9.61
# 698 2021-10-18   밥정   9.61
# 740 2021-10-19   밥정   9.61

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (12,8))
plt.plot(bob['date'], bob['point'])
plt.legend(['point'])
plt.grid()
plt.ylim(8,10)
plt.show()
